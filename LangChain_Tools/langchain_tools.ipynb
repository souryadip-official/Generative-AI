# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Tool 1
from langchain_community.tools import DuckDuckGoSearchRun
search = DuckDuckGoSearchRun()
result = search.invoke(input = "latest developments in generative AI 2026")
print(result)
# Out:
# This Week inAI: The Agent Autonomy Threshold —AIHas Started Making Decisions.2026-03-09. A roundup of the key signals from the first week of March2026, asAIagents move beyond simple task execution to autonomous, multi-step decision-making... UsingAItools fordevelopersenhances the workflows across software applications. TheseAIdevelopmenttools automate tasks like codegenerationand performance optimization, ensuring both efficiency and quality. OpenXcell is a topAIdevelopmentcompany that builds next-gen, customAIsolutions for industries like healthcare, retail, eCommerce, and education. The team takes time to understand your project needs and leveragesAI’s full potential to create solutions that drive business growth. ThelatestdevelopmentsinAI, Tech and Robotics.Get thelatestAInews, understand why it matters, and learn how to apply it in your work. Join 2,000,000+ readers from companies like Apple, OpenAI, NASA. GDC2026:AI-powered videogenerationwith ComfyUI’s App View, NVIDIA RTX Video Super Resolution and new NVFP4 models.

# %%
# Tool 2
from langchain_community.tools import ShellTool
shell = ShellTool()
results = shell.invoke(input = 'cd .. && ls')
print(results)
# Out:
# Executing command:
#  cd .. && ls
# LangChain_Chains
# LangChain_Models
# LangChain_Output_Parsers
# LangChain_Prompts
# LangChain_Runnables
# LangChain_Tools
# LangChain_with_structured_output (Only supported LLMs)
# News Intelligence RAG
# RAG
# YouTube Chatbot Using LangChain
